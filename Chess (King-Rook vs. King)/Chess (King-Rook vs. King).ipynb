# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('krkopt.data')

# %%
df.head()
# Out:
#    a  1  b  3  c  2  draw
# 0  a  1  c  1  c  2  draw
# 1  a  1  c  1  d  1  draw
# 2  a  1  c  1  d  2  draw
# 3  a  1  c  2  c  1  draw
# 4  a  1  c  2  c  3  draw

# %%
columns_name = ['White King file (column)', 'White King rank (row)', 'White Rook file', 'White Rook rank', 'Black King file', 'Black King rank',
                'optimal depth-of-win for White in 0 to 16 moves, otherwise drawn']

# %%
df = pd.read_csv('krkopt.data', names = columns_name)
df.to_csv('krkopt.csv', index=False)

# %%
df.head()
# Out:
#   White King file (column)  White King rank (row) White Rook file  \
# 0                        a                      1               b
# 1                        a                      1               c
# 2                        a                      1               c
# 3                        a                      1               c
# 4                        a                      1               c
#
#    White Rook rank Black King file  Black King rank  \
# 0                3               c                2
# 1                1               c                2
# 2                1               d                1
# 3                1               d                2
# 4                2               c                1
#
#   optimal depth-of-win for White in 0 to 16 moves, otherwise drawn
# 0                                               draw
# 1                                               draw
# 2                                               draw
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28056 entries, 0 to 28055
# Data columns (total 7 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   White King file (column)                                          28056 non-null  object
#  1   White King rank (row)                                             28056 non-null  int64
#  2   White Rook file                                                   28056 non-null  object
#  3   White Rook rank                                                   28056 non-null  int64
#  4   Black King file                                                   28056 non-null  object
#  5   Black King rank                                                   28056 non-null  int64
#  6   optimal depth-of-win for White in 0 to 16 moves, otherwise drawn  28056 non-null  object
# ...

# %%
df.describe()
# Out:
#        White King rank (row)  White Rook rank  Black King rank
# count           28056.000000     28056.000000     28056.000000
# mean                1.854006         4.512404         4.451811
# std                 0.926414         2.282723         2.248387
# min                 1.000000         1.000000         1.000000
# 25%                 1.000000         3.000000         3.000000
# 50%                 2.000000         5.000000         4.000000
# 75%                 2.000000         6.000000         6.000000
# max                 4.000000         8.000000         8.000000

# %%
df.isnull().sum()
# Out:
# White King file (column)                                            0
# White King rank (row)                                               0
# White Rook file                                                     0
# White Rook rank                                                     0
# Black King file                                                     0
# Black King rank                                                     0
# optimal depth-of-win for White in 0 to 16 moves, otherwise drawn    0
# dtype: int64

# %%
sns.pairplot(df.iloc[:,:-1])

# %%
#Correction Matrix
sns.set(style = 'white', color_codes = True)
sns.set(font_scale = 2)
plt.figure(figsize = (50,50))
sns.heatmap(df.corr(), cmap='plasma',  annot = True)
# Out:
# C:\Users\kongp\AppData\Local\Temp\ipykernel_1108\968641502.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), cmap='plasma',  annot = True)
# <AxesSubplot: >

# %%
# from sklearn.preprocessing import LabelEncoder for performing Label Encoding
from sklearn.preprocessing import LabelEncoder
lbl_white_king=LabelEncoder()
df['White King file (column)']=lbl_white_king.fit_transform(df['White King file (column)'])
lbl_white_rook=LabelEncoder()
df['White Rook file']=lbl_white_rook.fit_transform(df['White Rook file'])
lbl_black_king=LabelEncoder()
df['Black King file']=lbl_black_king.fit_transform(df['Black King file'])
lbl_result=LabelEncoder()
df['optimal depth-of-win for White in 0 to 16 moves, otherwise drawn']=lbl_result.fit_transform(df['optimal depth-of-win for White in 0 to 16 moves, otherwise drawn'])

# %%
#Correction Matrix
sns.set(style = 'white', color_codes = True)
sns.set(font_scale = 2)
plt.figure(figsize = (50,50))
sns.heatmap(df.corr(), cmap='plasma',  annot = True)
# Out:
# <AxesSubplot: >

# %%
sns.violinplot(x=df["White King rank (row)"])
# Out:
# <AxesSubplot: xlabel='White King rank (row)'>

# %%
sns.violinplot(x=df["Black King rank"])
# Out:
# <AxesSubplot: xlabel='Black King rank'>

# %%
plt.figure(figsize=(20,12))
sns.countplot(x='optimal depth-of-win for White in 0 to 16 moves, otherwise drawn',data=df,hue="White Rook rank")
# Out:
# <AxesSubplot: xlabel='optimal depth-of-win for White in 0 to 16 moves, otherwise drawn', ylabel='count'>

# %%
plt.figure(figsize=(16,8))
sns.countplot(x='optimal depth-of-win for White in 0 to 16 moves, otherwise drawn',data=df,hue="White King rank (row)")
# Out:
# <AxesSubplot: xlabel='optimal depth-of-win for White in 0 to 16 moves, otherwise drawn', ylabel='count'>

# %%
plt.figure(figsize=(20,12))
sns.countplot(x='optimal depth-of-win for White in 0 to 16 moves, otherwise drawn',data=df,hue="Black King rank")
# Out:
# <AxesSubplot: xlabel='optimal depth-of-win for White in 0 to 16 moves, otherwise drawn', ylabel='count'>

# %%
plt.figure(figsize=(20,6))
sns.countplot(x='optimal depth-of-win for White in 0 to 16 moves, otherwise drawn',data=df,hue="Black King file")
# Out:
# <AxesSubplot: xlabel='optimal depth-of-win for White in 0 to 16 moves, otherwise drawn', ylabel='count'>

# %%
plt.figure(figsize=(30,16))
sns.countplot(x='White Rook rank',data=df,hue="optimal depth-of-win for White in 0 to 16 moves, otherwise drawn")
# Out:
# <AxesSubplot: xlabel='White Rook rank', ylabel='count'>

# %%
plt.figure(figsize=(30,16))
sns.countplot(x='Black King rank',data=df,hue="optimal depth-of-win for White in 0 to 16 moves, otherwise drawn")
# Out:
# <AxesSubplot: xlabel='Black King rank', ylabel='count'>

# %%
# Set the font scale
sns.set(font_scale=1)  
# Create the pairplot
sns.pairplot(df.iloc[:,:-1])
# Reset the font scale to default
sns.set(font_scale=1.0)

# %% [markdown]
# Decision tree  Split the train and test set 50/50

# %%
#split the features and target variable
#feature variables
x=df.iloc[:,:-1].values
#target variable
y=df.iloc[:,-1].values

# %%
# Split the train and test set
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.5)

# %%
# import DecsisonTreeClassifer from sklearn.tree
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier(random_state=100)

# train the data 
model.fit(x_train,y_train)
y_predict=model.predict(x_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_predict))
#import accuracy score from sklearn.metrics
print('Accuracy: ', model.score(x_test,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.71      0.73      1434
#            1       0.80      0.79      0.79       713
#            2       0.75      0.76      0.75      1385
#            3       0.75      0.80      0.78      1074
#            4       0.79      0.81      0.80       242
#            5       0.78      0.78      0.78        87
#            6       0.82      0.80      0.81      2244
#            7       0.77      0.77      0.77       839
#            8       0.84      0.89      0.86        35
#            9       0.68      0.73      0.71       330
#           10       0.75      0.74      0.74       316
#           11       0.75      0.72      0.74       212
#           12       0.74      0.76      0.75      1001
#           13       0.79      0.79      0.79      2051
#           14       0.70      0.83      0.76        36
#           15       0.77      0.77      0.77      1886
# ...

# %%
from sklearn.metrics import confusion_matrix

# Generate a confusion matrix
cm = confusion_matrix(y_test, y_predict)
fig, ax = plt.subplots(figsize=(10, 8))
# Plot the confusion matrix
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=True, ax=ax)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# Decision tree  Split the train and test set 60/40

# %%
# Split the train and test set
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4)

# import DecsisonTreeClassifer from sklearn.tree
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier(random_state=100)

# train the data 
model.fit(x_train,y_train)
y_predict=model.predict(x_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_predict))
#import accuracy score from sklearn.metrics
print('Accuracy: ', model.score(x_test,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.72      0.73      1122
#            1       0.85      0.81      0.83       601
#            2       0.80      0.80      0.80      1126
#            3       0.80      0.82      0.81       906
#            4       0.92      0.81      0.86       195
#            5       0.78      0.87      0.82        78
#            6       0.83      0.82      0.83      1776
#            7       0.78      0.78      0.78       702
#            8       0.93      0.90      0.92        31
#            9       0.74      0.73      0.73       260
#           10       0.78      0.81      0.79       247
#           11       0.75      0.75      0.75       159
#           12       0.76      0.80      0.78       791
#           13       0.79      0.80      0.79      1658
#           14       0.79      0.87      0.83        31
#           15       0.80      0.80      0.80      1431
# ...

# %%
from sklearn.metrics import confusion_matrix

# Generate a confusion matrix
cm = confusion_matrix(y_test, y_predict)
fig, ax = plt.subplots(figsize=(10, 8))
# Plot the confusion matrix
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=True, ax=ax)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# Decision tree  Split the train and test set 80/20

# %%
# Split the train and test set
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# import DecsisonTreeClassifer from sklearn.tree
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier(random_state=100)

# train the data 
model.fit(x_train,y_train)
y_predict=model.predict(x_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_predict))
#import accuracy score from sklearn.metrics
print('Accuracy: ', model.score(x_test,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.79      0.81       556
#            1       0.83      0.85      0.84       290
#            2       0.85      0.83      0.84       565
#            3       0.83      0.88      0.85       435
#            4       0.95      0.92      0.93        85
#            5       0.80      0.83      0.81        29
#            6       0.86      0.85      0.86       928
#            7       0.84      0.81      0.82       356
#            8       1.00      0.95      0.97        19
#            9       0.78      0.79      0.78       137
#           10       0.85      0.88      0.86       125
#           11       0.78      0.80      0.79        61
#           12       0.82      0.86      0.84       387
#           13       0.83      0.84      0.83       814
#           14       0.69      0.92      0.79        12
#           15       0.83      0.82      0.83       756
# ...

# %%
from sklearn.metrics import confusion_matrix

# Generate a confusion matrix
cm = confusion_matrix(y_test, y_predict)
fig, ax = plt.subplots(figsize=(10, 8))
# Plot the confusion matrix
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=True, ax=ax)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# Random Forest Split the train and test set 50/50

# %%
#split the features and target variable
#feature variables
x=df.iloc[:,:-1].values
#target variable
y=df.iloc[:,-1].values

# Split the train and test set
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.5)

#Random Forest model
from sklearn.ensemble import RandomForestClassifier
moldel = RandomForestClassifier(n_estimators=100)

#train data
model.fit(x_train, y_train)
y_predict=model.predict(x_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_predict))
#import accuracy score from sklearn.metrics
print('Accuracy: ', model.score(x_test,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.68      0.70      1430
#            1       0.78      0.81      0.80       696
#            2       0.76      0.76      0.76      1431
#            3       0.78      0.78      0.78      1060
#            4       0.79      0.84      0.81       235
#            5       0.80      0.82      0.81        95
#            6       0.82      0.80      0.81      2314
#            7       0.77      0.75      0.76       860
#            8       0.88      0.88      0.88        41
#            9       0.67      0.73      0.70       331
#           10       0.84      0.76      0.80       296
#           11       0.65      0.79      0.71       178
#           12       0.74      0.73      0.74      1007
#           13       0.77      0.78      0.77      2111
#           14       0.67      0.74      0.70        43
#           15       0.76      0.78      0.77      1754
# ...

# %%
from sklearn.metrics import confusion_matrix

# Generate a confusion matrix
cm = confusion_matrix(y_test, y_predict)
fig, ax = plt.subplots(figsize=(10, 8))
# Plot the confusion matrix
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=True, ax=ax)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# Random Forest Split the train and test set 60/40

# %%
#split the features and target variable
#feature variables
x=df.iloc[:,:-1].values
#target variable
y=df.iloc[:,-1].values

# Split the train and test set
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4)

#Random Forest model
from sklearn.ensemble import RandomForestClassifier
moldel = RandomForestClassifier(n_estimators=100)

#train data
model.fit(x_train, y_train)
y_predict=model.predict(x_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_predict))
#import accuracy score from sklearn.metrics
print('Accuracy: ', model.score(x_test,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.73      0.75      1111
#            1       0.83      0.79      0.81       600
#            2       0.80      0.79      0.79      1122
#            3       0.85      0.83      0.84       889
#            4       0.87      0.84      0.85       199
#            5       0.82      0.89      0.85        70
#            6       0.81      0.85      0.83      1815
#            7       0.75      0.81      0.78       678
#            8       0.85      0.92      0.88        36
#            9       0.73      0.73      0.73       295
#           10       0.85      0.84      0.84       247
#           11       0.76      0.70      0.73       142
#           12       0.78      0.80      0.79       754
#           13       0.81      0.79      0.80      1742
#           14       0.76      0.69      0.72        32
#           15       0.79      0.80      0.79      1375
# ...

# %%
from sklearn.metrics import confusion_matrix

# Generate a confusion matrix
cm = confusion_matrix(y_test, y_predict)
fig, ax = plt.subplots(figsize=(10, 8))
# Plot the confusion matrix
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=True, ax=ax)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# Random Forest Split the train and test set 80/20

# %%
#split the features and target variable
#feature variables
x=df.iloc[:,:-1].values
#target variable
y=df.iloc[:,-1].values

# Split the train and test set
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

#Random Forest model
from sklearn.ensemble import RandomForestClassifier
moldel = RandomForestClassifier(n_estimators=100)

#train data
model.fit(x_train, y_train)
y_predict=model.predict(x_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_predict))
#import accuracy score from sklearn.metrics
print('Accuracy: ', model.score(x_test,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.82      0.82       548
#            1       0.85      0.84      0.84       315
#            2       0.83      0.83      0.83       555
#            3       0.85      0.90      0.87       438
#            4       0.91      0.94      0.93        89
#            5       0.90      0.90      0.90        39
#            6       0.89      0.86      0.88       924
#            7       0.85      0.86      0.85       356
#            8       0.92      0.79      0.85        14
#            9       0.83      0.81      0.82       141
#           10       0.89      0.91      0.90       112
#           11       0.82      0.84      0.83        70
#           12       0.82      0.80      0.81       390
#           13       0.84      0.85      0.84       838
#           14       0.75      0.88      0.81        17
#           15       0.84      0.85      0.84       718
# ...

# %%
from sklearn.metrics import confusion_matrix

# Generate a confusion matrix
cm = confusion_matrix(y_test, y_predict)
fig, ax = plt.subplots(figsize=(10, 8))
# Plot the confusion matrix
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=True, ax=ax)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
